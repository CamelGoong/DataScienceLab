# %% [markdown]
# <a href="https://colab.research.google.com/github/CamelGoong/DataScienceLab/blob/main/%5BWello_Project%5DBertsum-based%20Text%20Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # pyrouge

# %%
# install bheinzerling's pyrouge
# !git clone https://github.com/bheinzerling/pyrouge
# %cd pyrouge
# !python setup.py install
# install missing dependency
# !apt install libxml-parser-perl
# %cd pyrouge
# !git clone https://github.com/andersjo/pyrouge.git rouge
# !pyrouge_set_rouge_path '/content/pyrouge/pyrouge/rouge/tools/ROUGE-1.5.5'
# %cd /content/pyrouge/pyrouge/rouge/tools/ROUGE-1.5.5/data
# !mv WordNet-2.0.exc.db WordNet-2.0.exc.db.orig
# !perl WordNet-2.0-Exceptions/buildExeptionDB.pl ./WordNet-2.0-Exceptions ./smart_common_words.txt ./WordNet-2.0.exc.db
# Out:
# Cloning into 'pyrouge'...
# remote: Enumerating objects: 551, done.
# remote: Total 551 (delta 0), reused 0 (delta 0), pack-reused 551
# Receiving objects: 100% (551/551), 123.17 KiB | 1.13 MiB/s, done.
# Resolving deltas: 100% (198/198), done.
# /content/pyrouge
# running install
# running bdist_egg
# running egg_info
# creating pyrouge.egg-info
# writing pyrouge.egg-info/PKG-INFO
# writing dependency_links to pyrouge.egg-info/dependency_links.txt
# writing top-level names to pyrouge.egg-info/top_level.txt
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# adding license file 'LICENSE.txt'
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/pyrouge
# copying pyrouge/__init__.py -> build/lib/pyrouge
# copying pyrouge/test.py -> build/lib/pyrouge
# copying pyrouge/Rouge155.py -> build/lib/pyrouge
# ...

# %%
# !python -m pyrouge.test
# Out:
# 2021-11-24 06:07:03,837 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpu71jle7j/rouge_conf.xml
# .2021-11-24 06:07:04,198 [MainThread  ] [INFO ]  Processing files in data/SL2003_models_plain_text.
# 2021-11-24 06:07:04,198 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-11.html.
# 2021-11-24 06:07:04,199 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-12.html.
# 2021-11-24 06:07:04,199 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-05.html.
# 2021-11-24 06:07:04,199 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-10.html.
# 2021-11-24 06:07:04,199 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-17.html.
# 2021-11-24 06:07:04,200 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-04.html.
# 2021-11-24 06:07:04,200 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-18.html.
# 2021-11-24 06:07:04,200 [MainThread  ] [INFO ]  Processing SL.P.10.R.A.SL062003-06.html.
# ...

# %% [markdown]
# # 은전한닢 로드
#
# https://github.com/SOMJANG/Mecab-ko-for-Google-Colab

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 91 (delta 0), reused 0 (delta 0), pack-reused 90
# Unpacking objects: 100% (91/91), done.

# %%
# %cd Mecab-ko-for-Google-Colab
# Out:
# /content/pyrouge/pyrouge/rouge/tools/ROUGE-1.5.5/data/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# ...
#      |████████████████████████████████| 19.4 MB 7.6 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 448 kB 60.4 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2021-11-24 06:07:17--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22cd:e0db, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from konlpy.tag import Mecab

mecab = Mecab()

# %%
mecab.morphs('동해물과 백두산이 마르고 닳도록')
# Out:
# ['동해', '물', '과', '백두산', '이', '마르', '고', '닳', '도록']

# %% [markdown]
# # 패키지로드

# %%
# !pip install transformers
# !pip install tensorboardx
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 42.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 53.4 MB/s
# ...
#      |████████████████████████████████| 59 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 41.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 124 kB 4.2 MB/s
# ...

# %% [markdown]
# # Load the Repo

# %%
# !mkdir /content/Kobert_project 
# %cd /content/Kobert_project
# !git clone https://github.com/HaloKim/KorBertSum.git
# Out:
# /content/Kobert_project
# Cloning into 'KorBertSum'...
# remote: Enumerating objects: 11148, done.
# remote: Counting objects: 100% (10846/10846), done.
# remote: Compressing objects: 100% (7616/7616), done.
# remote: Total 11148 (delta 3263), reused 10780 (delta 3220), pack-reused 302
# Receiving objects: 100% (11148/11148), 18.97 MiB | 13.99 MiB/s, done.
# Resolving deltas: 100% (3438/3438), done.

# %% [markdown]
# # BERT

# %%
from transformers import BertTokenizer, BertModel, BertConfig

config = BertConfig.from_pretrained('bert-base-multilingual-cased')
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model = BertModel.from_pretrained("bert-base-multilingual-cased")
# Out:
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.87M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# # AI hub data

# %%
# !mkdir "/content/Kobert_project/AIhub_data"
# %cd "/content/Kobert_project/AIhub_data"

# 이하 AIhub train, valid data zip 풀기
# !unzip -q '/content/drive/MyDrive/Colab Notebooks/AIhub_data/신문기사_train_original.zip' -d "/content/Kobert_project/AIhub_data" # -q: 해균 > AIhub_data에서 데이터 파일 다운, 각자 파일 경로 설정. -d: 경로 그대로 두기
# !unzip -q '/content/drive/MyDrive/Colab Notebooks/AIhub_data/신문기사_valid_original.zip' -d "/content/Kobert_project/AIhub_data" # -q: 위와 동일하게 valid.zip에 대해서 각자 파일 경로 설정. -d: 그대로 두기

# 실행 결과, /content/Kobert_project/AIhub_data 폴더에 train과 valid에 대한 json 형성.

# %%
import json
with open("/content/Kobert_project/AIhub_data/train_original.json") as f:
  
  d = json.load(f)

# %%
d = d['documents']

# %%
import pandas as pd

df = pd.DataFrame(d)

# %%
df.head(2)

# %%
# 27만개의 데이터를 다 하려다보니, 전처리만해도 시간이 많이 걸리고, RAM이 다운되서, 적절한 숫자를 설정해야할듯
# 27만개 중 500개의 데이터만 사용.

df = df.iloc[0:500]

# %%
import itertools
df['text'] = df['text'].apply(lambda x: list(itertools.chain(*x)))

# %%
df_text = df['text']

# %%
len(df_text)

# %%
def sentences(df_text):
  article = []
  for sentence in df_text:
    article.append((sentence['sentence']))

  return (" ".join(article))

# %%
df_text = df_text.apply(lambda x : sentences(x))

# %%
df_text.head()

# %%
df['text'] = df_text

# %%
df.head(2)

# %%
# 원문내용 형태소 분석 
df['morphs'] = df['text'].apply(lambda x: " ".join(mecab.morphs(str(x))))

# %%
df['morphs'] = df['morphs'].apply(lambda x: list(x))

# %%
df.head(3)

# %%
df.to_csv('/content/Kobert_project/AIhub_data/output(train_aihub).csv')

# %%
import pandas as pd
import json

train = pd.read_csv('/content/Kobert_project/AIhub_data/output(train_aihub).csv').drop('Unnamed: 0', axis=1)
train

# %% [markdown]
# # Dacon data

# %%
# 해균이가 json파일을 .csv로 바꿔두었기 때문에 이부분 생략 
"""
with open('/content/drive/MyDrive/프로젝트2-B팀/요약 관련/해균/dacon_data/data.csv', 'r', encoding = "UTF-8-sig") as json_file:
    json_list = list(json_file)
result = []
"""
# Out:
# '\nwith open(\'/content/drive/MyDrive/프로젝트2-B팀/요약 관련/해균/dacon_data/data.csv\', \'r\', encoding = "UTF-8-sig") as json_file:\n    json_list = list(json_file)\nresult = []\n'

# %%
import pandas as pd
#df = pd.DataFrame(result)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dacon_data/data.csv')
df
# Out:
#     media  ...  extractive
# 0    당진시대  ...   [0, 1, 2]
# 1    국제신문  ...   [0, 1, 3]
# 2    기호일보  ...  [6, 7, 10]
# 3    대구일보  ...   [1, 6, 4]
# 4    대구신문  ...  [2, 3, 10]
# ..    ...  ...         ...
# 105  당진시대  ...   [0, 1, 2]
# 106  국제신문  ...   [0, 1, 3]
# 107  기호일보  ...  [6, 7, 10]
# 108  대구일보  ...   [1, 6, 4]
# 109  대구신문  ...  [2, 3, 10]
#
# [110 rows x 5 columns]

# %%
# train data
# 형태소별로 분리해서 morphs라는 column에 저장.
train = df
train['morphs'] = train['article_original'].apply(lambda x: " ".join(mecab.morphs(x)))

# %%
train
# Out:
#     media  ...                                             morphs
# 0    당진시대  ...  [ ' 당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 ...
# 1    국제신문  ...  [ ' 미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초...
# 2    기호일보  ...  [ ' 인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 ...
# 3    대구일보  ...  [ ' 대구 · 경북 첨단 의료 산업 진흥 재단 의약 생산 센터 는 항암 주사제 무...
# 4    대구신문  ...  [ ' 국내 유통 되 는 탄산 음료 중 식품 의 약 품안 전처 에 품질 인증 을 받...
# ..    ...  ...                                                ...
# 105  당진시대  ...  [ ' 당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 ...
# 106  국제신문  ...  [ ' 미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초...
# 107  기호일보  ...  [ ' 인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 ...
# 108  대구일보  ...  [ ' 대구 · 경북 첨단 의료 산업 진흥 재단 의약 생산 센터 는 항암 주사제 무...
# 109  대구신문  ...  [ ' 국내 유통 되 는 탄산 음료 중 식품 의 약 품안 전처 에 품질 인증 을 받...
#
# [110 rows x 6 columns]

# %%
train.to_csv('/content/Kobert_project/output(train).csv')

# %%
train.head()
# Out:
#   media  ...                                             morphs
# 0  당진시대  ...  [ ' 당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 ...
# 1  국제신문  ...  [ ' 미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초...
# 2  기호일보  ...  [ ' 인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 ...
# 3  대구일보  ...  [ ' 대구 · 경북 첨단 의료 산업 진흥 재단 의약 생산 센터 는 항암 주사제 무...
# 4  대구신문  ...  [ ' 국내 유통 되 는 탄산 음료 중 식품 의 약 품안 전처 에 품질 인증 을 받...
#
# [5 rows x 6 columns]

# %% [markdown]
# # Load csv

# %%
import pandas as pd
import json

train = pd.read_csv('/content/Kobert_project/output(train).csv').drop('Unnamed: 0', axis=1)
train
# Out:
#     media  ...                                             morphs
# 0    당진시대  ...  [ ' 당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 ...
# 1    국제신문  ...  [ ' 미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초...
# 2    기호일보  ...  [ ' 인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 ...
# 3    대구일보  ...  [ ' 대구 · 경북 첨단 의료 산업 진흥 재단 의약 생산 센터 는 항암 주사제 무...
# 4    대구신문  ...  [ ' 국내 유통 되 는 탄산 음료 중 식품 의 약 품안 전처 에 품질 인증 을 받...
# ..    ...  ...                                                ...
# 105  당진시대  ...  [ ' 당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 ...
# 106  국제신문  ...  [ ' 미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초...
# 107  기호일보  ...  [ ' 인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 ...
# 108  대구일보  ...  [ ' 대구 · 경북 첨단 의료 산업 진흥 재단 의약 생산 센터 는 항암 주사제 무...
# 109  대구신문  ...  [ ' 국내 유통 되 는 탄산 음료 중 식품 의 약 품안 전처 에 품질 인증 을 받...
#
# [110 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
# train : 100% / valid : 0% / test : 0% 

train_set = train

'''
train_set, test_set = train_test_split(train, test_size = 0.3)
valid_set, test_set = train_test_split(test_set, test_size = 0.2)'''
# Out:
# '\ntrain_set, test_set = train_test_split(train, test_size = 0.3)\nvalid_set, test_set = train_test_split(test_set, test_size = 0.2)'

# %%
train_set.head(3)
# Out:
#   media  ...                                             morphs
# 0  당진시대  ...  [ ' 당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 ...
# 1  국제신문  ...  [ ' 미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초...
# 2  기호일보  ...  [ ' 인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 ...
#
# [3 rows x 6 columns]

# %% [markdown]
# # csv to json

# %%
# !mkdir '/content/Kobert_project/json'
# Out:
# mkdir: cannot create directory ‘/content/Kobert_project/json’: File exists

# %%
# 위에서 나눈 train_set를 json으로 변환

import ast
from tqdm import tqdm
import os

os.mkdir('/content/Kobert_project/KorBertSum/json/train')


list_dic = []
for idx, row in train_set.iterrows():
  raw = row['morphs']
  target_idx = ast.literal_eval(row['extractive'])

  sentences = raw.split(',')
  src = [i.split(' ') for i in sentences]
  tgt = [a for i,a in enumerate(src) if i in target_idx]
  
  mydict = {}
  mydict['src'] = src
  mydict['tgt'] = tgt
  list_dic.append(mydict)
        
temp = []
for i,a in enumerate(tqdm(list_dic)):
  if (i+1)%6!=0:
      temp.append(a)
  else:
      # json 파일 지정 공간 설정 
      filename = 'korean.'+'train'+'.'+str(i//6)+'.json'
      with open('/content/Kobert_project/KorBertSum/json/train/'+filename, "w", encoding='utf-8') as json_file:
          json.dump(temp, json_file, ensure_ascii=False)
      temp = []
# Out:
# 100%|██████████| 110/110 [00:00<00:00, 1978.35it/s]

# %%
# 위에서 나눈 valid_set를 json으로 변환



try:
  os.mkdir('/content/Kobert_project/KorBertSum/json/val')

except:
  pass

list_dic = []
for idx, row in valid_set.iterrows():
        raw = row['morphs']
        target_idx = ast.literal_eval(row['extractive'])

        sentences = raw.split(',')
        src = [i.split(' ') for i in sentences]
        tgt = [a for i,a in enumerate(src) if i in target_idx]
        
        mydict = {}
        mydict['src'] = src
        mydict['tgt'] = tgt
        list_dic.append(mydict)
        
temp = []
for i,a in enumerate(tqdm(list_dic)):
    
    if (i+1)%6!=0:
        temp.append(a)
    else:
        filename = 'korean.'+'valid'+'.'+str(i//6)+'.json'
        with open('/content/Kobert_project/KorBertSum/json/val/'+filename, "w", encoding='utf-8') as json_file:
            json.dump(temp, json_file, ensure_ascii=False)
        temp = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c1a808cc2ae3> in <module>()
#      10
#      11 list_dic = []
# ---> 12 for idx, row in valid_set.iterrows():
#      13         raw = row['morphs']
#      14         target_idx = ast.literal_eval(row['extractive'])
#
# NameError: name 'valid_set' is not defined

# %%
# 위에서 나눈 test_set를 json으로 변환
try:
  os.mkdir('/content/Kobert_project/KorBertSum/json/test')
except:
  pass

list_dic = []
for idx, row in valid_set.iterrows():
        raw = row['morphs']
        target_idx = ast.literal_eval(row['extractive'])

        sentences = raw.split(',')
        src = [i.split(' ') for i in sentences]
        tgt = [a for i,a in enumerate(src) if i in target_idx]
        
        mydict = {}
        mydict['src'] = src
        mydict['tgt'] = tgt
        list_dic.append(mydict)
        
temp = []
for i,a in enumerate(tqdm(list_dic)):
    
    if (i+1)%6!=0:
        temp.append(a)
    else:
        filename = 'korean.'+'test'+'.'+str(i//6)+'.json'
        with open('/content/Kobert_project/KorBertSum/json/test/'+filename, "w", encoding='utf-8') as json_file:
            json.dump(temp, json_file, ensure_ascii=False)
        temp = []

# %% [markdown]
# # Json to pt

# %%
# (1분소요) Train_set 변환 / 원래 이 부분이 AIhub_data로 실행했을 때, RAM exceeded error 뜨면서, 진행이 안되었는데, 지금 AIhub data 350개 정도로 돌리는 거라서 돌아감.
# 데이터 처리모드, json경로, 저장경로, 로그파일 순

# !mkdir /content/Kobert_project/KorBertSum/bert_data/train # save path directory 생성 

# !python /content/Kobert_project/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/Kobert_project/KorBertSum/json/train \
  -save_path /content/Kobert_project/KorBertSum/bert_data/train \
  -dataset train \
# Out:
# [('/content/Kobert_project/KorBertSum/json/train/korean.train.6.json', Namespace(dataset='train', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', max_nsents=100, max_src_ntokens=200, min_nsents=3, min_src_ntokens=5, mode='format_to_bert', n_cpus=2, oracle_mode='greedy', raw_path='/content/Kobert_project/KorBertSum/json/train', save_path='/content/Kobert_project/KorBertSum/bert_data/train', shard_size=2000), '/content/Kobert_project/KorBertSum/bert_data/train/korean.train.6.bert.pt'), ('/content/Kobert_project/KorBertSum/json/train/korean.train.9.json', Namespace(dataset='train', log_file='../../logs/cnndm.log', lower=True, map_path='../data/', max_nsents=100, max_src_ntokens=200, min_nsents=3, min_src_ntokens=5, mode='format_to_bert', n_cpus=2, oracle_mode='greedy', raw_path='/content/Kobert_project/KorBertSum/json/train', save_path='/content/Kobert_project/KorBertSum/bert_data/train', shard_size=2000), '/content/Kobert_project/KorBertSum/bert_data/train/korean.trai
# ...

# %%
#  (35초 소요) Valid_set 변환
# 데이터 처리모드, json경로, 저장경로, 로그파일 순
try:
  os.mkdir('/content/Kobert_project/KorBertSum/bert_data/val')
except:
  pass

# !python /content/Kobert_project/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/Kobert_project/KorBertSum/json/val \
  -save_path /content/Kobert_project/KorBertSum/bert_data/val \
  -dataset valid \
# Out:
# []
# fin

# %%
# (35초 소요) Test_set 변환
# 데이터 처리모드, json경로, 저장경로, 로그파일 순
try:
  os.mkdir('/content/Kobert_project/KorBertSum/bert_data/test')
except:
  pass

# !python /content/Kobert_project/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/Kobert_project/KorBertSum/json/test \
  -save_path /content/Kobert_project/KorBertSum/bert_data/test \
  -dataset test \
# Out:
# []
# fin

# %% [markdown]
# # Train

# %%
# <원래코드> / model_path: checkpoint가 저장되는 경로.
# visible_gpus -1 이면 cpu training / gpu 학습시 0 
# train_steps 바꿀 때 "save_cekckpoint_steps" 도 함께 바꾸어야 함. 이걸 지정하지 않으면 모델 저장 안됌.
# train_steps 10일때, AIhub_data train이 GPU로 3분 소요.


# !!python /content/Kobert_project/KorBertSum/src/train.py \
  -mode train \
  -encoder classifier \
  -bert_data_path /content/Kobert_project/KorBertSum/bert_data/train/korean \
  -model_path /content/Kobert_project/KorBertSum/models/bert_classifier \
  -log_file /content/Kobert_project/KorBertSum/logs/train.txt \
  -lr 2e-3 -visible_gpus 0 -gpu_ranks 0 -world_size 1 -report_every 1000 -dropout 0.5 \
  -save_checkpoint_steps 1000 -batch_size 3000 -decay_method noam -train_steps 1000 -accum_count 1\
# Out:
# ['[2021-11-24 07:28:12,746 INFO] Device ID 0',
#  '[2021-11-24 07:28:12,746 INFO] Device cuda',
#  "Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']",
#  '- This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).',
#  '- This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).',
# ...

# %% [markdown]
# # Validation (사용안해도 될듯?)

# %%
#<원래 코드> test_from에 저장된 checkpoint 파일을 연결해주기.
# !mkdir /content/drive/MyDrive/Kobert_project/KorBertSum/temp

# %cd /content

# !python /content/drive/MyDrive/Kobert_project/KorBertSum/src/train.py \
  -mode validate \
  -bert_data_path /content/drive/MyDrive/Kobert_project/KorBertSum/bert_data/val/korean \
  -visible_gpus 0 -gpu_ranks 0 -batch_size 3000 \
  -log_file /content/drive/MyDrive/Kobert_project/KorBertSum/logs/val.txt \
  -temp_dir /content/drive/MyDrive/Kobert_project/KorBertSum/temp \
  -result_path /content/drive/MyDrive/Kobert_project/KorBertSum/results \
  -test_from /content/drive/MyDrive/Kobert_project/KorBertSum/models/bert_classifier/model_step_3.pt \
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Kobert_project/KorBertSum/temp’: No such file or directory
# /content
# python3: can't open file '/content/drive/MyDrive/Kobert_project/KorBertSum/src/train.py': [Errno 2] No such file or directory

# %% [markdown]
# # Test

# %%
# %cd /content

# !python /content/drive/MyDrive/Kobert_project/KorBertSum/src/train.py \
  -mode test \
  -bert_data_path /content/drive/MyDrive/Kobert_project/KorBertSum/bert_data/test/korean \
  -visible_gpus -1 -gpu_ranks 0 -batch_size 1000 \
  -log_file /content/drive/MyDrive/Kobert_project/KorBertSum/logs/val.txt \
  -temp_dir /content/drive/MyDrive/Kobert_project/KorBertSum/temp \
  -result_path /content/drive/MyDrive/Kobert_project/KorBertSum/results \
  -test_from /content/drive/MyDrive/Kobert_project/KorBertSum/models/bert_classifier/model_step_10.pt \
# Out:
# /content
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Kobert_project/KorBertSum/src/train.py", line 14, in <module>
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 721, in <module>
#     import torch.utils.data
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/__init__.py", line 38, in <module>
#     from torch.utils.data.dataloader_experimental import DataLoader2
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader_experimental.py", line 11, in <module>
#     from torch.utils.data.datapipes.iter import IterableWrapper
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/datapipes/__init__.py", line 1, in <module>
#     from . import iter
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/datapipes/iter/__init__.py", line 37, in <module>
#     from torch.utils.data.datapipes.iter.selecting import (
# ...

# %% [markdown]
# # Summarization Testing

# %% [markdown]
# # Preprocessing

# %%
import os

os.chdir('/content/Kobert_project/KorBertSum/src')

# %%
import torch
import numpy as np
from models import data_loader, model_builder
from models.model_builder import Summarizer
from others.logging import logger, init_logger
from models.data_loader import load_dataset
from transformers import BertConfig, BertTokenizer
from tensorboardX import SummaryWriter
from models.reporter import ReportMgr
from models.stats import Statistics
import easydict

# %%
def _tally_parameters(model):
    n_params = sum([p.nelement() for p in model.parameters()])
    return n_params

def build_trainer(args, device_id, model,
                  optim):
    """
    Simplify `Trainer` creation based on user `opt`s*
    Args:
        opt (:obj:`Namespace`): user options (usually from argument parsing)
        model (:obj:`onmt.models.NMTModel`): the model to train
        fields (dict): dict of fields
        optim (:obj:`onmt.utils.Optimizer`): optimizer used during training
        data_type (str): string describing the type of data
            e.g. "text", "img", "audio"
        model_saver(:obj:`onmt.models.ModelSaverBase`): the utility object
            used to save the model
    """
    device = "cpu" if args.visible_gpus == '-1' else "cuda"


    grad_accum_count = args.accum_count
    n_gpu = args.world_size

    if device_id >= 0:
        gpu_rank = int(args.gpu_ranks[device_id])
    else:
        gpu_rank = 0
        n_gpu = 0

    print('gpu_rank %d' % gpu_rank)

    tensorboard_log_dir = args.model_path

    writer = SummaryWriter(tensorboard_log_dir, comment="Unmt")

    report_manager = ReportMgr(args.report_every, start_time=-1, tensorboard_writer=writer)

    trainer = Trainer(args, model, optim, grad_accum_count, n_gpu, gpu_rank, report_manager)

    # print(tr)
    if (model):
        n_params = _tally_parameters(model)
        logger.info('* number of parameters: %d' % n_params)

    return trainer


class Trainer(object):
    """
    Class that controls the training process.

    Args:
            model(:py:class:`onmt.models.model.NMTModel`): translation model
                to train
            train_loss(:obj:`onmt.utils.loss.LossComputeBase`):
               training loss computation
            valid_loss(:obj:`onmt.utils.loss.LossComputeBase`):
               training loss computation
            optim(:obj:`onmt.utils.optimizers.Optimizer`):
               the optimizer responsible for update
            trunc_size(int): length of truncated back propagation through time
            shard_size(int): compute loss in shards of this size for efficiency
            data_type(string): type of the source input: [text|img|audio]
            norm_method(string): normalization methods: [sents|tokens]
            grad_accum_count(int): accumulate gradients this many times.
            report_manager(:obj:`onmt.utils.ReportMgrBase`):
                the object that creates reports, or None
            model_saver(:obj:`onmt.models.ModelSaverBase`): the saver is
                used to save a checkpoint.
                Thus nothing will be saved if this parameter is None
    """

    def __init__(self,  args, model,  optim,
                  grad_accum_count=1, n_gpu=1, gpu_rank=1,
                  report_manager=None):
        # Basic attributes.
        self.args = args
        self.save_checkpoint_steps = args.save_checkpoint_steps
        self.model = model
        self.optim = optim
        self.grad_accum_count = grad_accum_count
        self.n_gpu = n_gpu
        self.gpu_rank = gpu_rank
        self.report_manager = report_manager

        self.loss = torch.nn.BCELoss(reduction='none')
        assert grad_accum_count > 0
        # Set model in training mode.
        if (model):
            self.model.train()

    def summ(self, test_iter, step, cal_lead=False, cal_oracle=False):
      """ Validate model.
          valid_iter: validate data iterator
      Returns:
          :obj:`nmt.Statistics`: validation loss statistics
      """
      # Set model in validating mode.
      def _get_ngrams(n, text):
          ngram_set = set()
          text_length = len(text)
          max_index_ngram_start = text_length - n
          for i in range(max_index_ngram_start + 1):
              ngram_set.add(tuple(text[i:i + n]))
          return ngram_set

      def _block_tri(c, p):
          tri_c = _get_ngrams(3, c.split())
          for s in p:
              tri_s = _get_ngrams(3, s.split())
              if len(tri_c.intersection(tri_s))>0:
                  return True
          return False

      if (not cal_lead and not cal_oracle):
          self.model.eval()
      stats = Statistics()

      with torch.no_grad():
          for batch in test_iter:
              src = batch.src
              labels = batch.labels
              segs = batch.segs
              clss = batch.clss
              mask = batch.mask
              mask_cls = batch.mask_cls

              if (cal_lead):
                  selected_ids = [list(range(batch.clss.size(1)))] * batch.batch_size
              elif (cal_oracle):
                  selected_ids = [[j for j in range(batch.clss.size(1)) if labels[i][j] == 1] for i in
                                  range(batch.batch_size)]
              else:
                  sent_scores, mask = self.model(src, segs, clss, mask, mask_cls)
                  sent_scores = sent_scores + mask.float()
                  sent_scores = sent_scores.cpu().data.numpy()
                  selected_ids = np.argsort(-sent_scores, 1)
      return selected_ids



    def _gradient_accumulation(self, true_batchs, normalization, total_stats,
                               report_stats):
        if self.grad_accum_count > 1:
            self.model.zero_grad()

        for batch in true_batchs:
            if self.grad_accum_count == 1:
                self.model.zero_grad()

            src = batch.src
            labels = batch.labels
            segs = batch.segs
            clss = batch.clss
            mask = batch.mask
            mask_cls = batch.mask_cls

            sent_scores, mask = self.model(src, segs, clss, mask, mask_cls)

            loss = self.loss(sent_scores, labels.float())
            loss = (loss*mask.float()).sum()
            (loss/loss.numel()).backward()
            # loss.div(float(normalization)).backward()

            batch_stats = Statistics(float(loss.cpu().data.numpy()), normalization)


            total_stats.update(batch_stats)
            report_stats.update(batch_stats)

            # 4. Update the parameters and statistics.
            if self.grad_accum_count == 1:
                # Multi GPU gradient gather
                if self.n_gpu > 1:
                    grads = [p.grad.data for p in self.model.parameters()
                             if p.requires_grad
                             and p.grad is not None]
                    distributed.all_reduce_and_rescale_tensors(
                        grads, float(1))
                self.optim.step()

        # in case of multi step gradient accumulation,
        # update only after accum batches
        if self.grad_accum_count > 1:
            if self.n_gpu > 1:
                grads = [p.grad.data for p in self.model.parameters()
                         if p.requires_grad
                         and p.grad is not None]
                distributed.all_reduce_and_rescale_tensors(
                    grads, float(1))
            self.optim.step()

    def _save(self, step):
        real_model = self.model
        # real_generator = (self.generator.module
        #                   if isinstance(self.generator, torch.nn.DataParallel)
        #                   else self.generator)

        model_state_dict = real_model.state_dict()
        # generator_state_dict = real_generator.state_dict()
        checkpoint = {
            'model': model_state_dict,
            # 'generator': generator_state_dict,
            'opt': self.args,
            'optim': self.optim,
        }
        checkpoint_path = os.path.join(self.args.model_path, 'model_step_%d.pt' % step)
        logger.info("Saving checkpoint %s" % checkpoint_path)
        # checkpoint_path = '%s_step_%d.pt' % (FLAGS.model_path, step)
        if (not os.path.exists(checkpoint_path)):
            torch.save(checkpoint, checkpoint_path)
            return checkpoint, checkpoint_path

    def _start_report_manager(self, start_time=None):
        """
        Simple function to start report manager (if any)
        """
        if self.report_manager is not None:
            if start_time is None:
                self.report_manager.start()
            else:
                self.report_manager.start_time = start_time

    def _maybe_gather_stats(self, stat):
        """
        Gather statistics in multi-processes cases

        Args:
            stat(:obj:onmt.utils.Statistics): a Statistics object to gather
                or None (it returns None in this case)

        Returns:
            stat: the updated (or unchanged) stat object
        """
        if stat is not None and self.n_gpu > 1:
            return Statistics.all_gather_stats(stat)
        return stat

    def _maybe_report_training(self, step, num_steps, learning_rate,
                               report_stats):
        """
        Simple function to report training stats (if report_manager is set)
        see `onmt.utils.ReportManagerBase.report_training` for doc
        """
        if self.report_manager is not None:
            return self.report_manager.report_training(
                step, num_steps, learning_rate, report_stats,
                multigpu=self.n_gpu > 1)

    def _report_step(self, learning_rate, step, train_stats=None,
                     valid_stats=None):
        """
        Simple function to report stats (if report_manager is set)
        see `onmt.utils.ReportManagerBase.report_step` for doc
        """
        if self.report_manager is not None:
            return self.report_manager.report_step(
                learning_rate, step, train_stats=train_stats,
                valid_stats=valid_stats)

    def _maybe_save(self, step):
        """
        Save the model if a model saver is set
        """
        if self.model_saver is not None:
            self.model_saver.maybe_save(step)

class BertData():
    def __init__(self):
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
        self.sep_vid = self.tokenizer.vocab['[SEP]']
        self.cls_vid = self.tokenizer.vocab['[CLS]']
        self.pad_vid = self.tokenizer.vocab['[PAD]']

    def preprocess(self, src):

        if (len(src) == 0):
            return None

        original_src_txt = [' '.join(s) for s in src]
        idxs = [i for i, s in enumerate(src) if (len(s) > 1)]

        src = [src[i][:2000] for i in idxs]
        src = src[:1000]

        if (len(src) < 3):
            return None

        src_txt = [' '.join(sent) for sent in src]
        text = ' [SEP] [CLS] '.join(src_txt)
        src_subtokens = self.tokenizer.tokenize(text)
        src_subtokens = src_subtokens[:510]
        src_subtokens = ['[CLS]'] + src_subtokens + ['[SEP]']

        src_subtoken_idxs = self.tokenizer.convert_tokens_to_ids(src_subtokens)
        _segs = [-1] + [i for i, t in enumerate(src_subtoken_idxs) if t == self.sep_vid]
        segs = [_segs[i] - _segs[i - 1] for i in range(1, len(_segs))]
        segments_ids = []
        for i, s in enumerate(segs):
            if (i % 2 == 0):
                segments_ids += s * [0]
            else:
                segments_ids += s * [1]
        cls_ids = [i for i, t in enumerate(src_subtoken_idxs) if t == self.cls_vid]
        labels = None
        src_txt = [original_src_txt[i] for i in idxs]
        tgt_txt = None
        return src_subtoken_idxs, labels, segments_ids, cls_ids, src_txt, tgt_txt

def _lazy_dataset_loader(pt_file):
  yield  pt_file

# %% [markdown]
# # Parameters

# %%
# args "test from" 주소명, 훈련된 모델 이름이 바뀔때마다 매번 바꿔 주어야 함. 
args = easydict.EasyDict({
    "encoder":'classifier',
    "mode":'test',
    "bert_data_path":'/content/Kobert_project/KorBertSum/bert_data/korean',
    "model_path":'./models/bert_classifier',
    "result_path":'./results',
    "temp_dir":'./temp',
    "batch_size":1000,
    "use_interval":True,
    "hidden_size":128,
    "ff_size":512,
    "heads":4,
    "inter_layers":2,
    "rnn_size":512,
    "param_init":0,
    "param_init_glorot":True,
    "dropout":0.1,
    "optim":'adam',
    "lr":2e-3,
    "report_every":1,
    "save_checkpoint_steps":5,
    "block_trigram":True,
    "recall_eval":False,
    
    "accum_count":1,
    "world_size":1,
    "visible_gpus":'-1',
    "gpu_ranks":'0',
    "log_file":'/content/Kobert_project/KorBertSum/logs/log.log',
    "test_from":'/content/Kobert_project/KorBertSum/models/bert_classifier/model_step_1000.pt'
})
model_flags = ['hidden_size', 'ff_size', 'heads', 'inter_layers','encoder','ff_actv', 'use_interval','rnn_size']

# %% [markdown]
# # Test code

# %%
def test(args, input_list, device_id, pt, step):
  init_logger(args.log_file)
  device = "cpu" if args.visible_gpus == '-1' else "cuda"
  device_id = 0 if device == "cuda" else -1

  cp = args.test_from
  try:
    step = int(cp.split('.')[-2].split('_')[-1])
  except:
    step = 0

  device = "cpu" if args.visible_gpus == '-1' else "cuda"
  if (pt != ''):
      test_from = pt
  else:
      test_from = args.test_from
  logger.info('Loading checkpoint from %s' % test_from)
  checkpoint = torch.load(test_from, map_location=lambda storage, loc: storage)
  opt = vars(checkpoint['opt'])
  for k in opt.keys():
      if (k in model_flags):
        setattr(args, k, opt[k])

  config = BertConfig.from_pretrained('bert-base-multilingual-cased')
  model = Summarizer(args, device, load_pretrained_bert=False, bert_config = config)
  model.load_cp(checkpoint)
  model.eval()

  test_iter = data_loader.Dataloader(args, _lazy_dataset_loader(input_list),
                                args.batch_size, device,
                                shuffle=False, is_test=True)
  trainer = build_trainer(args, device_id, model, None)
  result = trainer.summ(test_iter,step)
  return result, input_list

args.gpu_ranks = [int(i) for i in args.gpu_ranks.split(',')]
os.environ["CUDA_VISIBLE_DEVICES"] = args.visible_gpus

# %%
def txt2input(text):
  data = list(filter(None, text.split('\n')))
  bertdata = BertData()
  txt_data = bertdata.preprocess(data)
  data_dict = {"src":txt_data[0],
               "labels":[0,1,2],
               "segs":txt_data[2],
               "clss":txt_data[3],
               "src_txt":txt_data[4],
               "tgt_txt":None}
  input_data = []
  input_data.append(data_dict)
  return input_data

# %% [markdown]
# Sample Test

# %%
text =  "지원대상  어린이집을 이용하는 만 35세 아동. \n 취학유예  만 6세아 초등학교 취학유예 시 1차에 한하여 지원.일반.만 35세 누리과정 운영에 필요한 비용 지원 . \n 보육료 담당교사 처우 개선비 운영비 지원.결혼육아교육보육교육지원보육지원. \n 1 지원대상  어린이집을 이용하는 만 35세 아동. \n 2 신청인  아동의 보호자.3 신청장소  읍면동 주민센터."

# %%
input_data = txt2input("'''" +text+"'''")
sum_list = test(args, input_data, -1, '', None)
sum_list[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-7f46287f8087> in <module>()
# ----> 1 input_data = txt2input("'''" +text+"'''")
#       2 sum_list = test(args, input_data, -1, '', None)
#       3 sum_list[0]
#
# NameError: name 'text' is not defined

# %%
[list(filter(None, text.split('\n')))[i] for i in sum_list[0][0][:3]] # 요약 문장의 갯수를 3개로 제한. 이 부분 변경 가능.

# %% [markdown]
# # 방법 1) 선정기준, 지원내용, 지원대상의 3가지 컬럼을 아예 처음부터 합친 다음에 요약

# %%
# 데이터 불러오기
import pandas as pd
policy_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/지오_전처리_숫자있.csv') # 각자 파일이 있는 경로로 설정.

# %%
policy_data
# Out:
#        Unnamed: 0  ...                                            y_label
# 0               0  ...  누리과정이란 만 35세를 대상으로 하는 어린이집 표준보육과정과 유치원 교육과정을 통...
# 1               1  ...   근로자녀장려세제.  저소득계층의 빈곤 탈출을 지원하고 사회안전망을 확충하기 위해 ...
# 2               2  ...               저소득층 등에게 월세자금보증을 하여 저소득층의 주거 안정성 제고.
# 3               3  ...                      코로나19로 피해를 입은 중소중견기업 지원 프로그램.
# 4               4  ...        연근해 어업인을 대상으로 노후기관장비설비 대체 보급으로 안정적 조업기반 조성.
# ...           ...  ...                                                ...
# 88481       88481  ...   이행으로 수입이 급증하여 가격 하락의 피해를 입은 품목의 생산자에게 가격 하락의 ...
# 88482       88482  ...                   이혼위기가족을 대상으로 가족기능 회복 및 아동 복리 증진.
# 88483       88483  ...  육아가사 등으로 경력 단절된 여성을 대상으로 직업상담 구인구직 관리 직업교육 인턴십...
# 88484       88484  ...  취학 전 아동기의 시력검진 및 눈 건강관리 교육을 통하여 저시력 및 안질환을 조기에...
# 88485       88485  ...                          시흥 갯골캠핑장 이용요금 할인혜택 정보 제공.
#
# [88486 rows x 3 columns]

# %% [markdown]
# txt2input은 문장이 "."이 아닌 \n 으로 구분되어야 요약이 가능하다.
# 따라서 .을 모두 ". \n "으로 바꿔준다.

# %%
policy_data['input_data'] = policy_data['input_data'].str.replace(".", ".\n")
policy_data.head()
# Out:
#    Unnamed: 0  ...                                            y_label
# 0           0  ...  누리과정이란 만 35세를 대상으로 하는 어린이집 표준보육과정과 유치원 교육과정을 통...
# 1           1  ...   근로자녀장려세제.  저소득계층의 빈곤 탈출을 지원하고 사회안전망을 확충하기 위해 ...
# 2           2  ...               저소득층 등에게 월세자금보증을 하여 저소득층의 주거 안정성 제고.
# 3           3  ...                      코로나19로 피해를 입은 중소중견기업 지원 프로그램.
# 4           4  ...        연근해 어업인을 대상으로 노후기관장비설비 대체 보급으로 안정적 조업기반 조성.
#
# [5 rows x 3 columns]

# %%
from tqdm import tqdm

# %%
# 20000개 정책 요약 전 필요한 전처리(txt2input)하는데에만 6시간 36분 걸림 
tqdm.pandas()

policy_data_half = policy_data.iloc[0:10]

policy_data_half['prep']= policy_data_half.progress_apply(lambda x : txt2input(x['input_data']), axis=1)
# Out:
# 100%|██████████| 10/10 [00:11<00:00,  1.13s/it]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 전처리 한데이터 날라가지 않게 저장 
# !mkdir "/content/Kobert_project/result"
policy_data_half.to_csv('/content/Kobert_project/result/polcity_half.csv')

# %%
policy_data_half.head()
# Out:
#    Unnamed: 0  ...                                               prep
# 0           0  ...  [{'src': [101, 9706, 9612, 9069, 9414, 9546, 9...
# 1           1  ...  [{'src': [101, 9665, 9018, 9087, 9559, 9670, 9...
# 2           2  ...  [{'src': [101, 9356, 9705, 8928, 122, 9547, 96...
# 3           3  ...  [{'src': [101, 9706, 9612, 9069, 9414, 9812, 9...
# 4           4  ...  [{'src': [101, 9546, 9428, 9022, 10003, 8932, ...
#
# [5 rows x 4 columns]

# %%
# 저장한 전처리된 데이터 불러오기 
preprocessed_policy_half = pd.read_csv('/content/Kobert_project/result/polcity_half.csv')

# %%
### 아래 방법으로 10개 정책 요약하는 데 약 23초 걸림... 한개당 1.x초 꼴.... 88000개면 빨라도 88000초, 빨라도 24시간;;;;;   

# 요약을 집어넣기 위한 빈 열 생성 
policy_data_half['summary'] = np.NaN


# j번째 행 마다  요약하는  코드 
for j in range(5) : 
  policy_data_half['summary'][j] = [list(filter(None, policy_data_half['input_data'][j].split('\n')))[i] for i in test(args, policy_data_half['prep'][j], -1, '', None)[0][0][:2]] # 이 맨 오른쪽 숫자로 추출 문장 갯수 조절
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# [2021-11-22 13:05:51,997 INFO] Loading checkpoint from /content/Kobert_project/KorBertSum/models/bert_classifier/model_step_10.pt
# [2021-11-22 13:05:56,848 INFO] * number of parameters: 177854209
# gpu_rank 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# ...

# %%
policy_data_half.head()
# Out:
#    Unnamed: 0  ...                                            summary
# 0           0  ...    [3 신청장소  읍면동 주민센터., 지원대상  어린이집을 이용하는 만 35세 아동.]
# 1           1  ...                    [  근로장려금은.,    단독가구 최대 150만 원.]
# 2           2  ...                            [ 희망키움통장 가입자.,  취업준비생.]
# 3           3  ...  [ 지원대상  코로나19 등 질병 자연재해 등 국가 재난 발생으로 피해를 입은 중소...
# 4           4  ...  [ 기관장비설비사업의 사업자 선정은 다음의 순위로 하되 동일 순위자의 세부 우선순위...
#
# [5 rows x 5 columns]

# %%
policy_data_half.to_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/policy_data_half_summary.csv')

# %% [markdown]
# # 방법 2) 선정기준, 지원내용, 지원대상의 3가지 컬럼에 대해서 각각 요약 진행 (낙준, 현우, 해균은 방법1말고 2만 쓰면 됩니다~)

# %%
# 데이터 불러오기
import pandas as pd
data_standard = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/data_standard.csv') # 각자 파일이 있는 경로로 설정
data_ppl = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/data_ppl.csv') # 각자 파일이 있는 경로로 설정
data_content = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/data_content.csv') # 각자 파일이 있는 경로로 설정

# %%
data_standard = data_standard.iloc[0:30]
data_ppl = data_ppl.iloc[0:30]
data_content = data_content.iloc[0:30]

# %%
data_standard.head()
# Out:
#    Unnamed: 0                                               선정기준
# 0       48671   원장  인건비 80 지원. 영아반 보육교사  인건비 80 지원. 유아반 보육교사 ...
# 1       88218                                                  .
# 2       78486                                        수급자격 해당 여부.
# 3       82568                           새터민으로 초 중 고등학교에 재학하는 학생.
# 4       83900                                                  .

# %%
# txt2input에 맞는 데이터 형식으로 변환
data_standard['선정기준'] = data_standard['선정기준'].str.replace(".", ".\n")
data_ppl['지원대상'] = data_ppl['지원대상'].str.replace(".", ".\n")
data_content['지원내용'] = data_content['지원내용'].str.replace(".", ".\n")

# %%
data_standard.head()
# Out:
#    Unnamed: 0                                               선정기준
# 0       48671   원장  인건비 80 지원.\n 영아반 보육교사  인건비 80 지원.\n 유아반 보...
# 1       88218                                                .\n
# 2       78486                                      수급자격 해당 여부.\n
# 3       82568                         새터민으로 초 중 고등학교에 재학하는 학생.\n
# 4       83900                                                .\n

# %% [markdown]
# 1) 선정기준 전처리 및 요약 동시진행

# %%
from tqdm import tqdm

# %%
# 선정기준
data_standard['summary'] = np.NaN

i=0

for row in tqdm(data_standard['선정기준']):
  try:
    
    data_standard['summary'][i] = [list(filter(None, row.split('\n')))[i] for i in test(args, txt2input(row), -1, '', None)[0][0][:3]]
  except:
    data_standard['summary'][i] = row
    
  i = i+1
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s][2021-11-24 07:51:04,322 INFO] Loading checkpoint from /content/Kobert_project/KorBertSum/models/bert_classifier/model_step_1000.pt
# [2021-11-24 07:51:09,768 INFO] * number of parameters: 177854209
# gpu_rank 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# ...

# %%
# <선정기준> 요약한 데이터 저장

data_standard.to_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/summarized_data_standard.csv')

# %% [markdown]
# 2) 지원대상 전처리 및 요약 동시진행

# %%
# 지원대상
data_ppl['summary'] = np.NaN

i=0

for row in tqdm(data_ppl['지원대상']):
  try:
    data_ppl['summary'][i] = [list(filter(None, row.split('\n')))[i] for i in test(args, txt2input(row), -1, '', None)[0][0][:3]]
  except:
    data_ppl['summary'][i] = row
    
  i = i+1
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s][2021-11-24 07:54:30,144 INFO] Loading checkpoint from /content/Kobert_project/KorBertSum/models/bert_classifier/model_step_1000.pt
# [2021-11-24 07:54:34,883 INFO] * number of parameters: 177854209
# gpu_rank 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# ...

# %%
# <지원대상> 요약한 데이터 저장

data_ppl.to_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/summarized_data_ppl.csv')

# %% [markdown]
# 3) 지원내용 전처리

# %%
# 지원내용
data_content['summary'] = np.NaN

i=0

for row in tqdm(data_content['지원내용']):
  try:
    data_content['summary'][i] = [list(filter(None, row.split('\n')))[i] for i in test(args, txt2input(row), -1, '', None)[0][0][:3]]
  except:
    data_content['summary'][i] = row
    
  i = i+1
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#   3%|▎         | 1/30 [00:05<02:38,  5.47s/it][2021-11-24 07:58:54,146 INFO] Loading checkpoint from /content/Kobert_project/KorBertSum/models/bert_classifier/model_step_1000.pt
# [2021-11-24 07:58:58,810 INFO] * number of parameters: 177854209
# ...

# %%
# <지원내용> 요약한 데이터 저장

data_content.to_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/summarized_data_content.csv')

# %% [markdown]
# # 최종 Summary 결과 확인 및 파일 합치기

# %%
# Summarized data 불러오기
import pandas as pd

summarized_data_standard = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/summarized_data_standard.csv')
summarized_data_ppl = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/summarized_data_ppl.csv')
summarized_data_content = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/summarized_data_content.csv')

# %%
summarized_data_standard.head()
# Out:
#    Unnamed: 0  ...                                            summary
# 0           0  ...  [' 원장  인건비 80 지원.', ' 유아반 보육교사  인건비 30 지원.', '...
# 1           1  ...                                                .\n
# 2           2  ...                                      수급자격 해당 여부.\n
# 3           3  ...                         새터민으로 초 중 고등학교에 재학하는 학생.\n
# 4           4  ...                                                .\n
#
# [5 rows x 4 columns]

# %%
# 통합 요약 데이터프레임 형성
import numpy as np

master_summary = pd.DataFrame() 
master_summary['policy_index'] = np.NaN
master_summary['선정기준'] = np.NaN
master_summary['선정기준_요약문'] = np.NaN
master_summary['지원대상'] = np.NaN
master_summary['지원대상_요약문'] = np.NaN
master_summary['지원내용'] = np.NaN
master_summary['지원내용_요약문'] = np.NaN

# %%
master_summary.head()
# Out:
# Empty DataFrame
# Columns: [policy_index, 선정기준, 선정기준_요약문, 지원대상, 지원대상_요약문, 지원내용, 지원내용_요약문]
# Index: []

# %%
master_summary['policy_index'] = summarized_data_standard['Unnamed: 0.1']
master_summary['선정기준'] = summarized_data_standard['선정기준']
master_summary['선정기준_요약문'] = summarized_data_standard['summary']
master_summary['지원대상'] = summarized_data_ppl['지원대상']
master_summary['지원대상_요약문'] = summarized_data_ppl['summary']
master_summary['지원내용'] = summarized_data_content['지원내용']
master_summary['지원내용_요약문'] = summarized_data_content['summary']

# %%
master_summary.head()
# Out:
#    policy_index  ...                                           지원내용_요약문
# 0         48671  ...   국공립 법인 및 취약보육담당 어린이집 중 보육교직원 인건비 국고지원 어린이집에 대...
# 1         88218  ...  [' 기간  2020.', '   광주 첫 확진자 확진일 기준.', ' 금액  월 ...
# 2         78486  ...  중소사업장 보일러의 일반 버너를 오염물질 저감효과가 큰 저녹스 버너로 교체 설치하는...
# 3         82568  ...  맞춤형 교육비 지원  학생 1인당 500000원.\n결혼육아교육중학교고등학교학습생활...
# 4         83900  ...  [' 민간 씨수말 교배 관련 교배료 목장 명 교배 정보 및 혈통정보의 종합적 제공....
#
# [5 rows x 7 columns]

# %%
# 최종파일 저장
master_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/policy_data/master_summary.csv')
